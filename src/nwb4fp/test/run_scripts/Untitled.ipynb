# %%
import dlc2kinematics
import matplotlib.pyplot as plt
import numpy as np

# %%
df, bodyparts, scorer = dlc2kinematics.load_data(r'S:/Sachuriga/Ephys_Vedio/CR_CA1/65409_Open_Field_50Hz_A2023-12-05T13_14_39DLC_dlcrnetms5_CR_implant_DLCnetNov30shuffle3_600000_sk.h5')

# %%
scorer
# Out:
# 'DLC_dlcrnetms5_CR_implant_DLCnetNov30shuffle3_600000'

# %%
bodyparts
# Out:
# ['snout',
#  'left_ear',
#  'right_ear',
#  'mid_brain',
#  'neck',
#  'back1',
#  'back2',
#  'back3',
#  'back4',
#  'tail1',
#  'tail2',
#  'tail3',
#  'tail4']

# %%
df
# Out:
# scorer      DLC_dlcrnetms5_CR_implant_DLCnetNov30shuffle3_600000           \
# individuals                                          individual1
# bodyparts                                                  snout
# coords                                                         x        y
# 0                                                      496.888     79.596
# 1                                                      497.623     79.446
# 2                                                      499.272     79.523
# 3                                                      502.005     75.086
# 4                                                      506.155     74.890
# ...                                                        ...        ...
# 64426                                                  495.927    469.726
# 64427                                                  497.250    467.558
# 64428                                                  497.443    466.915
# ...

# %%
#df_speed = dlc2kinematics.compute_speed(df,bodyparts=['snout'])
df_speed = dlc2kinematics.compute_velocity(df,bodyparts=['snout'])

# %%
df_speed
# Out:
# scorer      DLC_dlcrnetms5_CR_implant_DLCnetNov30shuffle3_600000          \
# individuals                                          individual1
# bodyparts                                                  snout
# coords                                                         x       y
# 0                                                       1.1920   -0.0365
# 1                                                       1.1920   -0.0365
# 2                                                       2.1910   -2.1800
# 3                                                       3.4415   -2.3165
# 4                                                       0.4610   -0.4155
# ...                                                        ...       ...
# 64426                                                   0.7930   -3.6780
# 64427                                                   0.7580   -1.4055
# 64428                                                   1.7540   -1.6050
# ...

# %%
plt.plot(np.float32(df_speed[f"{scorer}"].individual1.snout.speed.tolist())*2500/532)
