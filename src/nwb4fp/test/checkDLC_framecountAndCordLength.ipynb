# %%
import os
import cv2
import pandas as pd

def get_video_frame_count(video_path):
    """Get the total number of frames in a video"""
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Failed to open video file: {video_path}")
        return None
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    cap.release()
    return frame_count

def check_video_and_dlc(folder_path, output_filename="dlc_check_results.xlsx"):
    """Check all .avi videos and their corresponding DLC files in the folder"""
    # Store results
    results = []
    
    # Get all .avi files
    avi_files = [f for f in os.listdir(folder_path) if f.endswith('.avi')]
    
    # DLC file suffix pattern
    dlc_suffix = "DLC_DlcrnetStride32Ms5_CR_implant_DLCnetNov30shuffle1_snapshot_350_sk_filtered.h5"
    
    for avi_file in avi_files:
        print(f"\nProcessing video: {avi_file}")
        
        # Construct the corresponding DLC filename
        base_name = avi_file.replace('.avi', '')
        dlc_file = f"{base_name}{dlc_suffix}"
        dlc_path = os.path.join(folder_path, dlc_file)
        
        # Check if DLC file exists
        if not os.path.exists(dlc_path):
            print(f"Corresponding DLC file not found: {dlc_file}")
            results.append({
                "Video File": avi_file,
                "DLC File": "Not found",
                "Frame Count": None,
                "Coords Length": None,
                "Match": None,
                "Error": "DLC file missing"
            })
            continue
        
        try:
            # Get video frame count
            video_path = os.path.join(folder_path, avi_file)
            frame_count = get_video_frame_count(video_path)
            if frame_count is None:
                results.append({
                    "Video File": avi_file,
                    "DLC File": dlc_file,
                    "Frame Count": None,
                    "Coords Length": None,
                    "Match": None,
                    "Error": "Failed to read video"
                })
                continue
                
            # Read DLC file
            df = pd.read_hdf(dlc_path)
            bodyparts = df.columns.get_level_values("bodyparts").unique().to_list()
            scorer = df.columns.get_level_values(0)[0]
            
            # Get coordinate data (using snout x-coordinate as example)
            coords = df[scorer, 'individual1'][[('snout', 'x')]]
            coords_length = len(coords)
            
            # Compare frame count and coords length
            match = frame_count == coords_length
            print(f"Frame count: {frame_count}")
            print(f"Coords length: {coords_length}")
            print(f"Match: {match}")
            
            # Store result
            results.append({
                "Video File": avi_file,
                "DLC File": dlc_file,
                "Frame Count": frame_count,
                "Coords Length": coords_length,
                "Match": match,
                "Error": None
            })
            
        except Exception as e:
            print(f"Error processing file: {dlc_file}, Error: {str(e)}")
            results.append({
                "Video File": avi_file,
                "DLC File": dlc_file,
                "Frame Count": None,
                "Coords Length": None,
                "Match": None,
                "Error": str(e)
            })
    
    # Define the full output path for the Excel file
    output_excel = os.path.join(folder_path, output_filename)
    
    # Convert results to DataFrame and save to Excel
    results_df = pd.DataFrame(results)
    results_df.to_excel(output_excel, index=False)
    print(f"\nResults saved to {output_excel}")
    
    return results_df

# Example usage
folder_path = r"S:/Sachuriga/Ephys_Vedio/CR_CA1/pytorch_model/"  # Replace with your actual folder path
check_video_and_dlc(folder_path, output_filename="dlc_check_results.xlsx")
# Out:
# Processing video: 63383_Open_Field_50Hz_A2024-07-13T14_10_11.avi
# Frame count: 76908
# Coords length: 76908
# Match: True
#
# Processing video: 63383_Open_Field_50Hz_A2024-07-15T14_51_23.avi
# Frame count: 60307
# Coords length: 60307
# Match: True
#
# Processing video: 63383_Open_Field_50Hz_A2024-07-18T14_13_16.avi
# Frame count: 59875
# Coords length: 59875
# Match: True
#
# Processing video: 63383_Open_Field_50Hz_A2024-07-20T14_22_03.avi
# Frame count: 61160
# Coords length: 61160
# Match: True
#
# Processing video: 63383_Open_Field_50Hz_A2024-07-22T15_12_15.avi
# Frame count: 62363
# Coords length: 62363
# Match: True
#
# Processing video: 63383_Open_Field_50Hz_A2024-07-25T12_57_53.avi
# Frame count: 64462
# Coords length: 64462
# Match: True
#
# Processing video: 63383_Open_Field_50Hz
# Match: True
#
# Processing video: 66539_Open_Field_50Hz_C2024-12-22T17_49_08.avi
# Frame count: 61300
# Coords length: 61300
# Match: True
#
# Processing video: 66537_Open_Field_50Hz_A2024-12-18T12_33_17.avi
# Frame count: 61251
# Coords length: 61251
# Match: True
#
# Processing video: 66537_Open_Field_50Hz_A2024-12-19T16_42_39.avi
# Frame count: 60135
# Coords length: 60135
# Match: True
#
# Processing video: 66537_Open_Field_50Hz_A2024-12-21T15_19_25.avi
# Frame count: 66164
# Coords length: 66164
# Match: True
#
# Processing video: 66537_Open_Field_50Hz_A2024-12-22T15_10_28.avi
# Frame count: 62599
# Coords length: 62599
# Match: True
#
# Processing video: 66537_Open_Field_50Hz_B2024-12-18T12_57_56.avi
# Frame count: 63833
# Coords length: 63833
# Match: True
#
# Processing video: 66537_Open_Field_50Hz_B2024-12-19T17_07_26.avi
# Frame count: 60454
# Coords length: 60454
# Match: True
#
# Processing video: 66537_Open_Field_50Hz_B2024-12-21T15_47_28.avi
# Frame count: 59952
# Coords length: 59952
# Match: True
#
# Processing video: 66537_Open_Field_50Hz_C2024-12-18T13_22_29.avi
# Frame count: 61111
# Coords length: 61111
# Match: True
#
# Processing video: 66537_Open_Field_50Hz_C2024-12-19T17_30_32.avi
# Frame count: 63185
# Coords length: 63185
# Match: True
#
# Processing video: 66537_Open_Field_50Hz_C2024-12-21T16_10_44.avi
# Frame count: 73698
# Coords length: 73698
# Match: True
#
# Processing video: 66537_Open_Field_50Hz_C2024-12-22T16_19_49.avi
# Frame count: 60770
# Coords length: 60770
# Match: True
#
# Processing video: 66538_Open_Field_50Hz_A2024-12-21T14_48_49.avi
# Frame count: 60507
# Coords length: 60507
# Match: True
#
# Processing video: 66539_Open_Field_50Hz_A2024-12-18T14_06_32.avi
# Frame count: 66994
# Coords length: 66994
# Match: True
#
# Results saved to S:/Sachuriga/Ephys_Vedio/CR_CA1/pytorch_model/dlc_check_results.xlsx
#                                          Video File  \
# 0    63383_Open_Field_50Hz_A2024-07-13T14_10_11.avi
# 1    63383_Open_Field_50Hz_A2024-07-15T14_51_23.avi
# 2    63383_Open_Field_50Hz_A2024-07-18T14_13_16.avi
# 3    63383_Open_Field_50Hz_A2024-07-20T14_22_03.avi
# 4    63383_Open_Field_50Hz_A2024-07-22T15_12_15.avi
# ..                                              ...
# 316  66537_Open_Field_50Hz_C2024-12-19T17_30_32.avi
# 317  66537_Open_Field_50Hz_C2024-12-21T16_10_44.avi
# 318  66537_Open_Field_50Hz_C2024-12-22T16_19_49.avi
# 319  66538_Open_Field_50Hz_A2024-12-21T14_48_49.avi
# 320  66539_Open_Field_50Hz_A2024-12-18T14_06_32.avi
#
#                                               DLC File  Frame Count  \
# 0    63383_Open_Field_50Hz_A2024-07-13T14_10_11DLC_...        76908
# 1    63383_Open_Field_50Hz_A2024-07-15T14_51_23DLC_...        60307
# 2    63383_Open_Field_50Hz_A2024-07-18T14_13_16DLC_...        59875
# 3    63383_Open_Field_50Hz_A2024-07-20T14_22_03DLC_...        61160
# 4    63383_Open_Field_50Hz_A2024-07-22T15_12_15DLC_...        62363
# ..                                                 ...          ...
# 316  66537_Open_Field_50Hz_C2024-12-19T17_30_32DLC_...        63185
# 317  66537_Open_Field_50Hz_C2024-12-21T16_10_44DLC_...        73698
# 318  66537_Open_Field_50Hz_C2024-12-22T16_19_49DLC_...        60770
# 319  66538_Open_Field_50Hz_A2024-12-21T14_48_49DLC_...        60507
# 320  66539_Open_Field_50Hz_A2024-12-18T14_06_32DLC_...        66994
#
#      Coords Length  Match Error
# 0            76908   True  None
# 1            60307   True  None
# 2            59875   True  None
# 3            61160   True  None
# 4            62363   True  None
# ..             ...    ...   ...
# 316          63185   True  None
# 317          73698   True  None
# 318          60770   True  None
# 319          60507   True  None
# 320          66994   True  None
#
# [321 rows x 6 columns]
